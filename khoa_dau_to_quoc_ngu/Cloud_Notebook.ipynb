# %% [markdown]
# # Huấn luyện Mô hình Chuyển tự Khoa Đẩu -> Quốc ngữ (Quy mô lớn)
# Dự án: Applying NLP Techniques to Khoa Dau Transliteration
#
# Notebook này được thiết kế để chạy trên **Google Colab** hoặc **Kaggle** với GPU (T4, P100, hoặc A100).

# %%
# 1. Kiểm tra GPU
# !nvidia-smi

# %%
# 2. Cài đặt thư viện
# !pip install torch pandas tqdm numpy scikit-learn

# %% [markdown]
# ### 3. Chuẩn bị Dữ liệu và Code
# Nếu bạn đã upload mã nguồn lên Cloud, hãy di chuyển vào thư mục dự án.

# %%
import os
# cd /content/Applying-NLP-Techniques-to-Khoa-Dau-Transliteration/khoa_dau_to_quoc_ngu
print("Thư mục hiện tại:", os.getcwd())

# %% [markdown]
# ### 4. Bắt đầu Huấn luyện
# Huấn luyện trên toàn bộ dữ liệu (không dùng `--limit`).

# %%
# %env PYTHONUTF8=1
# !python train.py
